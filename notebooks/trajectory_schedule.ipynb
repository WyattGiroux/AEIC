# %%
from typing import cast

import pandas as pd
import operator as op

from AEIC.config import Config, config
from AEIC.performance.models import PerformanceModel, TASOPTPerformanceModel
from AEIC.trajectories import TrajectorySchedule

from unittest.mock import MagicMock

# %%
Config.load();

# %%
traj_schedule = TrajectorySchedule(
        config.file_location('trajectory/standard_trajectory.toml')
    )

# %%
print(type(traj_schedule.climb[0]))
# Out:
# <class 'AEIC.trajectories.segments.segments.CFR_ROCD_Const_CAS'>

# %%
print(traj_schedule.climb[0].end_alt)

traj_schedule.climb[0].end_alt = 10.0

print(type(traj_schedule.climb[0].end_alt))
# Out:
# crz_start_altitude
# <class 'float'>
